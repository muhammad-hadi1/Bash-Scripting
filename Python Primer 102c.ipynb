# %%
age = 10
if age == 10:
    print("what do you call an unhappy cranberry?")
    print("A blueberry!")
elif age==11:
    print("What did the green grape say to thr blue grape?")
    print("Breathe ! Breathe!")
elif age==12:
    print("what did 0 say to 8?")
    print("Hi guys!")
elif age==13:
    print("why wasn't 10 afraid of 7?")
    print("Because rather then eating 9,7 8 pi.")
else:
    print("Huh?")
# Out:
# what do you call an unhappy cranberry?
# A blueberry!

# %%
age=10
if age == 10 or age==11 or age==12 or age==13:
    print("what is 13 + 49 + 84 + 155 + 97? A headache!") 
else:
    print("Huh?")
# Out:
# what is 13 + 49 + 84 + 155 + 97? A headache!

# %%
age=15
if age == 10 or age==11 or age==12 or age==13:
    print("what is 13 + 49 + 84 + 155 + 97? A headache!") 
else:
    print("Huh?")
# Out:
# Huh?

# %%
age=10
if age>=10 and age<=13:
    print("what is 13 + 49 + 84 + 155 + 97? A headache!") 
else:
    print("Huh?")
# Out:
# what is 13 + 49 + 84 + 155 + 97? A headache!

# %%
if age >=10 and age <=13:
    print("Because rather then eating 9,7 8 pi.")
else:
    print("Huh?")
# Out:
# Because rather then eating 9,7 8 pi.
