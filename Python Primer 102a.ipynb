# %%
age = 13
if age > 10:
   print('YOU ARE TOO OLD!')
# Out:
# YOU ARE TOO OLD!

# %%
age = 25
if age > 20:
    print('YOU ARE TOO OLD!')
    print('WHY ARE YOU HERE?')
    print("whyaren't you movwing a lawn or sorting papers?")
# Out:
# YOU ARE TOO OLD!
# WHY ARE YOU HERE?
# whyaren't you movwing a lawn or sorting papers?
