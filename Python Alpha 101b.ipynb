# %%
#String Slicing
first_string="My Country is Pakistan"
first_string[0:10]
# Out:
# 'My Country'

# %%
#String Slicing
first_string="My Country is Pakistan"
first_string[0:-5]
# Out:
# 'My Country is Pak'

# %%
#Slicing down to a single character
my_string="hello world"
my_string[0]
# Out:
# 'h'

# %%
#The old way of string substitution step 1
strings="i like %s" %"Python"
strings
# Out:
# 'i like Python'

# %%
#The old way of string substitution step 2
var="cookies"
strings="i like %s" % var 
strings
# Out:
# 'i like cookies'

# %%
#The old way of string substitution step 3
var="cake"
another_string="i like %s and %s" % ("Python","var")
another_string
# Out:
# 'i like Python and var'

# %%
#Examples with integers
ints="%i + %i = %i" %(1,2,3)
ints
# Out:
# '1 + 2 = 3'

# %%
#Examples with float
float_string = "%f" % (1.23)
float_string
# Out:
# '1.230000'

# %%
#Or another float example
float_string2 = "%.2f" % (1.23)
float_string2
# Out:
# '1.23'

# %%
#More examples with number
print("%(x)i + %(y)i = %(z)i" % {"x":1, "y":2, "z":3})
# Out:
# 1 + 2 = 3

# %%
"Python is as simple as {0}, {1}, {2}".format("a", "b", "c")
# Out:
# 'Python is as simple as a, b, c'

# %%
"i like the {sweet} and {food}".format(sweet="cake", food="cookies")
# Out:
# 'i like the cake and cookies'
