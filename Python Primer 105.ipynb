# %%
class things:
    pass 
class inanimate(things):
    pass
class animate(things):
    pass
class sidewalks(inanimate):
    pass
class animals(animate):
    pass
class mammls(animate):
    pass
class dogs(mammls):
    pass

# %%
def this_is_a_normal_function():
    print('im a normal function')
class this_is_a_class_function:
    def __init__(self):
        print('im a class function')
        print('i belong to the class this_is_a_class_function')
        def inner_function(self):
            print('im an inner function')

# %%
class animals(animate):
    def breathe(self):
        pass
    def eat(self):
        pass
    def sleep(self):
        pass
