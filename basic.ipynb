# %%
a=10
b=90
a+b
# Out:
# 100

# %%
abubakar='''first caliph
a comapaninon of Prophet Mohammad Peace be upon him

a good man '''
print(abubakar)
# Out:
# first caliph
# a comapaninon of Prophet Mohammad Peace be upon him
#
# a good man

# %%
myscore = 1000
message = 'i scorerd %s points'
print(message % myscore)
# Out:
# i scorerd 1000 points

# %%
myscore = 56
aliscore = 88
message = 'In the cricket match my score is %s run %s run'
print(message % (myscore , aliscore) )
# Out:
# In the cricket match my score is 56 run 88 run

# %%
myscore = 56
aliscore = 88
message = 'In the cricket match my score is %s run %s run'
print(message % (myscore , aliscore) )
# Out:
# In the cricket match my score is 56 run 88 run

# %%
print(20 * 'i love Allah')
# Out:
# i love Allahi love Allahi love Allahi love Allahi love Allahi love Allahi love Allahi love Allahi love Allahi love Allahi love Allahi love Allahi love Allahi love Allahi love Allahi love Allahi love Allahi love Allahi love Allahi love Allah

# %%
sharfoo_list=['aloo','friut,banana','apple','chai']
print(sharfoo_list[0:2])
# Out:
# ['aloo', 'friut,banana']

# %%
computer = 99
math = 90
english = 95
message = '''YOU GET %s IN COMPUTER 
YOU GET %s IN MATH 
YOU GET %s IN ENGLISH'''
print(message % ( computer , math , english ))
# Out:
# YOU GET 99 IN COMPUTER
# YOU GET 90 IN MATH
# YOU GET 95 IN ENGLISH
