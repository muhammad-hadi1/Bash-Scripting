# %%
# strings examples
my_examples="welcome to Python !"
another_string='Python is fun'
a_long_stiing="' This is a multi line string . it covers more than one line '"

# %%
#more string examples
string_with_double_quotes=" He said , \"Python is awesome !\" "
other_string=' It\'s a sunny day '
tripleString=""" This is a string that spans
multiple lines using triple quotes. """

# %%
#STR
my_numbers=122
mr_string=str(my_numbers)
print(mr_string)
# Out:
# 122

# %%
x=int("123")
my_string="abc"

# %%
# string contcatenation
string_one='sharfoo is a good man .'
string_two=' He helps everyone .'
string_three=string_one + string_two
print(string_three)
# Out:
# sharfoo is a good man . He helps everyone .

# %%
# string in uppercase and lowercase
my_string="Hello World!"
my_string.upper()
# Out:
# 'HELLO WORLD!'

# %%
# string in uppercase and lowercase
string1='hello hOw are you'
string1.lower()
# Out:
# 'hello how are you'
