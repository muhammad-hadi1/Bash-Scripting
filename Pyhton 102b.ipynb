# %%
age=23
if age > 20:
    print ('YOU ARE OLDER FOR MY JOKES!')
# Out:
# YOU ARE OLDER FOR MY JOKES!

# %%
age=10
if age == 10:
    print (' You will now have a limited time to play in the ground')
# Out:
#  You will now have a limited time to play in the ground

# %%
print('Want to hear a dirty')

age=10
if age== 12:
    print('A pig fell in the mud!')
else:
    print('ssh. Its a secret')
# Out:
# Want to hear a dirty
# ssh. Its a secret

# %%
print('Want to hear a dirty')

age>=10
if age== 10:
    print('A pig fell in the mud!')
else:
    print('ssh. Its a secret')
# Out:
# Want to hear a dirty
# A pig fell in the mud!

# %%
print('Want to hear a dirty')

age=11
if age<=10:
    print('ssh. Its a secret')
else:
    print('A pig fell in the mud!')
# Out:
# Want to hear a dirty
# A pig fell in the mud!

# %%
print('Want to hear a dirty')

age=11
if age!=10:
    print('ssh. Its a secret')
else:
    print('A pig fell in the mud!')
# Out:
# Want to hear a dirty
# ssh. Its a secret
