# %%
age=19
if age>=18:
    print("what's the best eay to speak to a monster?")
    print("From as far away as possible!")
# Out:
# what's the best eay to speak to a monster?
# From as far away as possible!

# %%
age='19'
if age==19:
    print("what's the best eay to speak to a monster?")
    print("From as far away as possible!")

# %%
age='17'
converted_age=int(age)

# %%
age=17
converted_age=str(age)

# %%
age='10'
converted_age=int(age)
if converted_age==10:
    print("what's the best eay to speak to a monster?")
    print("From as far away as possible!")
# Out:
# what's the best eay to speak to a monster?
# From as far away as possible!

# %%
age='10.8'
converted_age=int(age)
if converted_age==10:
    print("what's the best eay to speak to a monster?")
    print("From as far away as possible!")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 2
#       1 age='10.8'
# ----> 2 converted_age=int(age)
#       3 if converted_age==10:
#       4     print("what's the best eay to speak to a monster?")
#
# ValueError: invalid literal for int() with base 10: '10.8'

# %%
age='10'
converted_age=float(age)
if converted_age==10:
    print("what's the best eay to speak to a monster?")
    print("From as far away as possible!")
# Out:
# what's the best eay to speak to a monster?
# From as far away as possible!
